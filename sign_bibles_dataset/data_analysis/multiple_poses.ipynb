# %% [markdown]
# https://github.com/BibleNLP/sign-bibles-dataset/issues/28

# %%
from pose_format import Pose

# %%
# !find "/opt/home/cleong/projects/semantic_and_visual_similarity/sign-bibles-dataset/downloads/ase/Chronological Bible Translation in American Sign Language (119 Introductions and Passages expanded with More Information)" -name "*-Passage*God Creates*World*.mp4" ! -name "*animation*"|parallel cp -v "{}" pose_estimation_multiple
# Out:
# '/opt/home/cleong/projects/semantic_and_visual_similarity/sign-bibles-dataset/downloads/ase/Chronological Bible Translation in American Sign Language (119 Introductions and Passages expanded with More Information)/CBT-001-ase-3-Passage _ God Creates the World.mp4' -> 'pose_estimation_multiple/CBT-001-ase-3-Passage _ God Creates the World.mp4'

# %%
# !videos_to_poses --format mediapipe --num-workers 24 --recursive --additional-config="model_complexity=2,smooth_landmarks=false,refine_face_landmarks=true,num_poses=2" --directory "pose_estimation_multiple/"
# Out:
# Found 1 videos missing pose files.
# Multiprocessing with 24 workers on 128 available CPUs ...
# Estimating pose_estimation_multiple/CBT-001-ase-3-Passage _ God Creates the World.mp4 on CPU N/A
# Loading video ...
# ...
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# concurrent.futures.process._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/home/cleong/envs/pose_eval_src/lib/python3.12/concurrent/futures/process.py", line 264, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/home/cleong/envs/pose_eval_src/lib/python3.12/concurrent/futures/process.py", line 213, in _process_chunk
#     return [fn(*args) for args in chunk]
#             ^^^^^^^^^
#   File "/opt/home/cleong/envs/pose_eval_src/lib/python3.12/site-packages/pose_format/bin/directory.py", line 100, in process_video
# ...

# %%
import mediapipe as mp 
mp.solutions.holistic
# Out:
# <module 'mediapipe.python.solutions.holistic' from '/opt/home/cleong/envs/pose_eval_src/lib/python3.12/site-packages/mediapipe/python/solutions/holistic.py'>
